# %%
from rdflib import Graph, URIRef, Literal, BNode, plugin, Namespace
from rdflib.serializer import Serializer
from collections import defaultdict, OrderedDict
import pandas as pd
import json
import requests
from io import StringIO

# %%
class Schema():
    def __init__(self, debug=False):
        self.forbidden = ["subject", "language", "authorIdentifierScheme", "contributorType", "publicationIDType", "DatasetField"]
        self.datadict = {}
        self.g = Graph()
    
    def load_metadata_schema(self, schemaURL, schemablock=False):
        keynameID = 1        
        if not schemablock:
            schemablock = 'default'
        schema = requests.get(schemaURL).text.split('\n')
        if schemablock == 'citation':
            schema = schema[2:]
        else:
            schema = schema[2:]
        dataschema = []
    
        for i in range(0, len(schema)):
            item = schema[i]
            elements = item.split('\t')
            try:
                if elements[keynameID] not in forbidden:
                    if i == len(schema):
                        dataschema.append(item)
                    else:
                        dataschema.append(item + "\n")
            except:
                skip = elements
        schemaIO = StringIO(''.join(dataschema))
        #print(dataschema)
        data = pd.read_csv(schemaIO, sep="\t", error_bad_lines=False)
        self.datadict[schemablock] = data
        return self.datadict

# %%
schemaURL = 'https://raw.githubusercontent.com/IQSS/dataverse/develop/scripts/api/data/metadatablocks/citation.tsv'
schema = Schema()
schemapd = schema.load_metadata_schema(schemaURL, 'citation')
schemaURL = 'https://raw.githubusercontent.com/IQSS/dataverse/develop/scripts/api/data/metadatablocks/biomedical.tsv'
schemapd = schema.load_metadata_schema(schemaURL, 'biomedical')
schemapd['citation']
# Out:
# b'Skipping line 71: expected 17 fields, saw 18\n'
#     #datasetField                     name  \
# 0             NaN                    title
# 1             NaN                 subtitle
# 2             NaN         alternativeTitle
# 3             NaN           alternativeURL
# 4             NaN                  otherId
# ..            ...                      ...
# 67            NaN          relatedDatasets
# 68            NaN          otherReferences
# 69            NaN          originOfSources
# 70            NaN  characteristicOfSources
# 71            NaN          accessToSources
#
#                                   title  \
# 0                                 Title
# 1                              Subtitle
# 2                     Alternative Title
# 3                       Alternative URL
# 4                              Other ID
# ..                                  ...
# 67                     Related Datasets
# 68                     Other References
# 69                    Origin of Sources
# 70      Characteristic of Sources Noted
# 71  Documentation and Access to Sources
#
#                                           description  \
# 0           Full title by which the Dataset is known.
# 1   A secondary title used to amplify or state cer...
# 2   A title by which the work is commonly referred...
# 3   A URL where the dataset can be viewed, such as...
# 4   Another unique identifier that identifies this...
# ..                                                ...
# 67  Any Datasets that are related to this Dataset,...
# 68  Any references that would serve as background ...
# 69  For historical materials, information about th...
# 70  Assessment of characteristics and source mater...
# 71    Level of documentation of the original sources.
#
#                                 watermark  fieldType  displayOrder  \
# 0                          Enter title...       text             0
# 1                                     NaN       text             1
# 2                                     NaN       text             2
# 3   Enter full URL, starting with http://        url             3
# 4                                     NaN       none             4
# ..                                    ...        ...           ...
# 67                                    NaN    textbox            72
# 68                                    NaN       text            73
# 69                                    NaN    textbox            75
# 70                                    NaN    textbox            76
# 71                                    NaN    textbox            77
#
#                                   displayFormat  advancedSearchField  \
# 0                                           NaN                 True
# 1                                           NaN                False
# 2                                           NaN                False
# 3   <a href="#VALUE" target="_blank">#VALUE</a>                False
# 4                                             :                False
# ..                                          ...                  ...
# 67                                          NaN                False
# 68                                          NaN                False
# 69                                          NaN                False
# 70                                          NaN                False
# 71                                          NaN                False
#
#     allowControlledVocabulary  allowmultiples  facetable  displayoncreate  \
# 0                       False           False      False             True
# 1                       False           False      False            False
# 2                       False           False      False            False
# 3                       False           False      False            False
# 4                       False            True      False            False
# ..                        ...             ...        ...              ...
# 67                      False            True      False            False
# 68                      False            True      False            False
# 69                      False           False      False            False
# 70                      False           False      False            False
# 71                      False           False      False            False
#
#     required parent metadatablock_id                               termURI
# 0       True    NaN         citation        http://purl.org/dc/terms/title
# 1      False    NaN         citation                                   NaN
# 2      False    NaN         citation  http://purl.org/dc/terms/alternative
# 3      False    NaN         citation       https://schema.org/distribution
# 4      False    NaN         citation                                   NaN
# ..       ...    ...              ...                                   ...
# 67     False    NaN         citation     http://purl.org/dc/terms/relation
# 68     False    NaN         citation   http://purl.org/dc/terms/references
# 69     False    NaN         citation                                   NaN
# 70     False    NaN         citation                                   NaN
# 71     False    NaN         citation                                   NaN
#
# [72 rows x 17 columns]

# %%
schemapd['biomedical']
# Out:
#      #datasetField                  name                  title  \
# 0              NaN       studyDesignType            Design Type
# 1              NaN  studyOtherDesignType      Other Design Type
# 2              NaN       studyFactorType            Factor Type
# 3              NaN  studyOtherFactorType      Other Factor Type
# 4              NaN    studyAssayOrganism               Organism
# ..             ...                   ...                    ...
# 290            NaN    studyAssayPlatform  Xevo G2 QTOF (Waters)
# 291            NaN    studyAssayPlatform  Xevo QTof MS (Waters)
# 292            NaN    studyAssayPlatform    Xevo TQ MS (Waters)
# 293            NaN    studyAssayPlatform     Xevo TQ-S (Waters)
# 294            NaN    studyAssayPlatform                  Other
#
#                                            description  watermark fieldType  \
# 0    Design types that are based on the overall exp...        NaN      text
# 1    If Other was selected in Design Type, list any...        NaN      text
# 2                         Factors used in the Dataset.        NaN      text
# 3    If Other was selected in Factor Type, list any...        NaN      text
# 4    The taxonomic name of the organism used in the...        NaN      text
# ..                                                 ...        ...       ...
# 290                                       XEVO_G2_QTOF      179.0       NaN
# 291                                       XEVO_QTOF_MS      180.0       NaN
# 292                                         XEVO_TQ_MS      181.0       NaN
# 293                                          XEVO_TQ_S      182.0       NaN
# 294                                     OTHER_PLATFORM      183.0       NaN
#
#      displayOrder  displayFormat advancedSearchField  \
# 0             0.0            NaN                True
# 1             1.0            NaN                True
# 2             2.0            NaN                True
# 3             3.0            NaN                True
# 4             4.0            NaN                True
# ..            ...            ...                 ...
# 290           NaN            NaN                 NaN
# 291           NaN            NaN                 NaN
# 292           NaN            NaN                 NaN
# 293           NaN            NaN                 NaN
# 294           NaN            NaN                 NaN
#
#     allowControlledVocabulary allowmultiples facetable displayoncreate  \
# 0                        True           True      True           False
# 1                       False           True      True           False
# 2                        True           True      True           False
# 3                       False           True      True           False
# 4                        True           True      True           False
# ..                        ...            ...       ...             ...
# 290                       NaN            NaN       NaN             NaN
# 291                       NaN            NaN       NaN             NaN
# 292                       NaN            NaN       NaN             NaN
# 293                       NaN            NaN       NaN             NaN
# 294                       NaN            NaN       NaN             NaN
#
#     required  parent metadatablock_id
# 0      False     NaN       biomedical
# 1      False     NaN       biomedical
# 2      False     NaN       biomedical
# 3      False     NaN       biomedical
# 4      False     NaN       biomedical
# ..       ...     ...              ...
# 290      NaN     NaN              NaN
# 291      NaN     NaN              NaN
# 292      NaN     NaN              NaN
# 293      NaN     NaN              NaN
# 294      NaN     NaN              NaN
#
# [295 rows x 16 columns]
